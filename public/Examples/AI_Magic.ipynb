# %% [markdown]
# # All kinds of AI magic

# %%
# Run it to pre-load `plotly`
import micropip
await micropip.install("plotly")

# %% [markdown]
# ## Searching data with AI

# %%
# %%cribl_search var=df lang=english dataset=cribl_search_sample
# Show the 2000 most recent entries

# %% [markdown]
# ## Generating visualisations with AI
#
# Here is some fun stuff you can do with AI to visualise the data.
# * Click on the AI button to check out the prompt. Generate the code and run the cell. It should generate a `matplotlib` viz.
# * See how the commented prompt populates the AI textbox.
# * Clone the `matplotlib` cell and replace `matplotlib` with `plotly` or `vega-lite`. See how the other packages can visualise the same data.
#
# Note 1: sometimes, if the code throws an error, you need to change the last statement from `fig.show()` to `fig`, or `chart.show()` to `chart`.
#
# Note 2: If `plotly` viz is still unhappy, make sure you run the previous cell with `micropip.install()`

# %%
# ### Prompt:
# Generate Python code that Visualise dataframe df, show 10 top srcaddr values by sum of bytes (converted to int) using barchart and matplotlib.

# %% [markdown]
# ## Getting help with errors
# Below we have a couple of cells with errors. Run them and inspect the error messages, how they show you the code line where error occurred, and how the help of AI can be used to explain and even fix the error.

# %%
x = 10
y = 0
result = x / y

# %%
data = {"ok": 1}
value = data["missing_key"]

# %%
int("not a number")
