# %% [markdown]
# # Jupyter widgets (ipywidgets)
#
# This example uses the kernel’s built-in demo helper to emit a Jupyter-shaped `comm_open` plus a widget MIME bundle, rendered with `@jupyter-widgets/controls` in the app.
#
# Run the code cell below after the kernel is **Ready**.

# %%
_nb_demo_int_slider()
